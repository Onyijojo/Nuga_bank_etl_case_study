# %%
# %pip install pyspark pandas sqlalchemy psycopg2-binary
# Out:
# Requirement already satisfied: pyspark in c:\users\admin\onedrive\documents\10alytics_training\pyspark\nuga_project\nuga_bank_etl_case_study\.venv\lib\site-packages (4.0.1)
# Collecting pandas
#   Using cached pandas-2.3.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Collecting sqlalchemy
#   Using cached sqlalchemy-2.0.44-cp313-cp313-win_amd64.whl.metadata (9.8 kB)
# Collecting psycopg2-binary
#   Using cached psycopg2_binary-2.9.11-cp313-cp313-win_amd64.whl.metadata (5.1 kB)
# Requirement already satisfied: py4j==0.10.9.9 in c:\users\admin\onedrive\documents\10alytics_training\pyspark\nuga_project\nuga_bank_etl_case_study\.venv\lib\site-packages (from pyspark) (0.10.9.9)
# Collecting numpy>=1.26.0 (from pandas)
#   Using cached numpy-2.3.5-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\onedrive\documents\10alytics_training\pyspark\nuga_project\nuga_bank_etl_case_study\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting greenlet>=1 (from sqlalchemy)
#   Using cached greenlet-3.3.0-cp313-cp313-win_amd64.whl.metadata (4.2 kB)
# Collecting typing-extensions>=4.6.0 (from sqlalchemy)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: six>=1.5 in c:\users\admin\onedrive\documents\10alytics_training\pyspark\nuga_project\nuga_bank_etl_case_study\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached pandas-2.3.3-cp313-cp313-win_amd64.whl (11.0 MB)
# Using cached sqlalchemy-2.0.44-cp313-cp313-win_amd64.whl (2.1 MB)
# Using cached psycopg2_binary-2.9.11-cp313-cp313-win_amd64.whl (2.7 MB)
# Using cached greenlet-3.3.0-cp313-cp313-win_amd64.whl (301 kB)
# Using cached numpy-2.3.5-cp313-cp313-win_amd64.whl (12.8 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, typing-extensions, psycopg2-binary, numpy, greenlet, sqlalchemy, pandas
#
#    ---------------------------------------- 0/8 [pytz]
#    ---------------------------------------- 0/8 [pytz]
#    ---------------------------------------- 0/8 [pytz]
#    ---------------------------------------- 0/8 [pytz]
#    ---------------------------------------- 0/8 [pytz]
#    ---------------------------------------- 0/8 [pytz]
#    ---------------------------------------- 0/8 [pytz]
#    ---------------------------------------- 0/8 [pytz]
#    ---------------------------------------- 0/8 [pytz]
#    ---------------------------------------- 0/8 [pytz]
#    ---------------------------------------- 0/8 [pytz]
#    ----- ---------------------------------- 1/8 [tzdata]
#    ----- ---------------------------------- 1/8 [tzdata]
#    ----- ---------------------------------- 1/8 [tzdata]
#    ----- ---------------------------------- 1/8 [tzdata]
#    ----- ---------------------------------- 1/8 [tzdata]
#    ----- ---------------------------------- 1/8 [tzdata]
#    ----- ---------------------------------- 1/8 [tzdata]
#    ----- ---------------------------------- 1/8 [tzdata]
#    ----- ---------------------------------- 1/8 [tzdata]
#    ----- ---------------------------------- 1/8 [tzdata]
#    ----- ---------------------------------- 1/8 [tzdata]
#    ---------- ----------------------------- 2/8 [typing-extensions]
#    --------------- ------------------------ 3/8 [psycopg2-binary]
#    --------------- ------------------------ 3/8 [psycopg2-binary]
#    --------------- ------------------------ 3/8 [psycopg2-binary]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    -------------------- ------------------- 4/8 [numpy]
#    ------------------------- -------------- 5/8 [greenlet]
#    ------------------------- -------------- 5/8 [greenlet]
#    ------------------------- -------------- 5/8 [greenlet]
#    ------------------------- -------------- 5/8 [greenlet]
#    ------------------------- -------------- 5/8 [greenlet]
#    ------------------------- -------------- 5/8 [greenlet]
#    ------------------------- -------------- 5/8 [greenlet]
#    ------------------------- -------------- 5/8 [greenlet]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ----------------------------------- ---- 7/8 [pandas]
#    ---------------------------------------- 8/8 [pandas]
#
# Successfully installed greenlet-3.3.0 numpy-2.3.5 pandas-2.3.3 psycopg2-binary-2.9.11 pytz-2025.2 sqlalchemy-2.0.44 typing-extensions-4.15.0 tzdata-2025.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# import Necessary Libraries

from pyspark.sql import SparkSession
from pyspark.sql import DataFrameWriter
from pyspark.sql.functions import monotonically_increasing_id
import pandas as pd
from sqlalchemy import create_engine
import os
import psycopg2

# %%
import os

# Point JAVA_HOME to your Java 8 install
os.environ["JAVA_HOME"] = r"C:\Program Files\Java\jdk-1.8" 

# Make sure Java 8's bin is at the very front of PATH
os.environ["PATH"] = os.environ["JAVA_HOME"] + r"\bin;" + os.environ["PATH"]

# Sanity check
import pprint
print("JAVA_HOME in this kernel:")
print(os.environ["JAVA_HOME"])
# Out:
# JAVA_HOME in this kernel:
# C:\Program Files\Java\jdk-1.8

# %%
# set java home
#os.environ['JAVA_HOME'] = r'C:\Program Files\Java\jdk-1.8'
#os.environ['JAVA_HOME'] = 'C:\java8\java8'

# %%
# !java -version
# Out:
# java version "1.8.0_461"
# Java(TM) SE Runtime Environment (build 1.8.0_461-b11)
# Java HotSpot(TM) 64-Bit Server VM (build 25.461-b11, mixed mode)

# %%
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
        .master("local[*]")
        .appName("Sanity Test")
        .getOrCreate()
)

spark.range(10).show()

# %%
spark = SparkSession.builder \
    .appName('Nuga Bank ETL') \
    .config("spark.jars", "postgresql-42.7.8.jar") \
    .getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 4
#       1 spark = SparkSession.builder \
#       2     .appName('Nuga Bank ETL') \
#       3     .config("spark.jars", "postgresql-42.7.8.jar") \
# ----> 4     .getOrCreate()
#
# File c:\Users\Admin\OneDrive\Documents\10Alytics_Training\pyspark\Nuga_Project\Nuga_bank_etl_case_study\.venv\Lib\site-packages\pyspark\sql\session.py:556, in SparkSession.Builder.getOrCreate(self)
#     554     sparkConf.set(key, value)
#     555 # This SparkContext may be an existing one.
# --> 556 sc = SparkContext.getOrCreate(sparkConf)
#     557 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     558 # by all sessions.
#     559 session = SparkSession(sc, options=self._options)
#
# File c:\Users\Admin\OneDrive\Documents\10Alytics_Training\pyspark\Nuga_Project\Nuga_bank_etl_case_study\.venv\Lib\site-packages\pyspark\core\context.py:523, in SparkContext.getOrCreate(cls, conf)
#     521 with SparkContext._lock:
#     522     if SparkContext._active_spark_context is None:
# --> 523         SparkContext(conf=conf or SparkConf())
#     524     assert SparkContext._active_spark_context is not None
#     525     return SparkContext._active_spark_context
#
# File c:\Users\Admin\OneDrive\Documents\10Alytics_Training\pyspark\Nuga_Project\Nuga_bank_etl_case_study\.venv\Lib\site-packages\pyspark\core\context.py:205, in SparkContext.__init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls, udf_profiler_cls, memory_profiler_cls)
#     199 if gateway is not None and gateway.gateway_parameters.auth_token is None:
#     200     raise ValueError(
#     201         "You are trying to pass an insecure Py4j gateway to Spark. This"
#     202         " is not allowed as it is a security risk."
#     203     )
# --> 205 SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     206 try:
#     207     self._do_init(
#     208         master,
#     209         appName,
#    (...)    219         memory_profiler_cls,
#     220     )
#
# File c:\Users\Admin\OneDrive\Documents\10Alytics_Training\pyspark\Nuga_Project\Nuga_bank_etl_case_study\.venv\Lib\site-packages\pyspark\core\context.py:444, in SparkContext._ensure_initialized(cls, instance, gateway, conf)
#     442 with SparkContext._lock:
#     443     if not SparkContext._gateway:
# --> 444         SparkContext._gateway = gateway or launch_gateway(conf)
#     445         SparkContext._jvm = SparkContext._gateway.jvm
#     447     if instance:
#
# File c:\Users\Admin\OneDrive\Documents\10Alytics_Training\pyspark\Nuga_Project\Nuga_bank_etl_case_study\.venv\Lib\site-packages\pyspark\java_gateway.py:108, in launch_gateway(conf, popen_kwargs)
#     106 # Wait for the file to appear, or for the process to exit, whichever happens first.
#     107 while not proc.poll() and not os.path.isfile(conn_info_file):
# --> 108     time.sleep(0.1)
#     110 if not os.path.isfile(conn_info_file):
#     111     raise PySparkRuntimeError(
#     112         errorClass="JAVA_GATEWAY_EXITED",
#     113         messageParameters={},
#     114     )
#
# KeyboardInterrupt:

# %%
# Initialise our Spark Session
spark = SparkSession.builder \
    .appName('Nuga Bank ETL') \
    .config("spark.jars.packages", "org.postgresql:postgresql:42.6.0") \
        .getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 5
#       1 # Initialise our Spark Session
#       2 spark = SparkSession.builder \
#       3     .appName('Nuga Bank ETL') \
#       4     .config("spark.jars.packages", "org.postgresql:postgresql:42.6.0") \
# ----> 5         .getOrCreate()
#
# File c:\Users\Admin\OneDrive\Documents\10Alytics_Training\pyspark\Nuga_Project\Nuga_bank_etl_case_study\.venv\Lib\site-packages\pyspark\sql\session.py:556, in SparkSession.Builder.getOrCreate(self)
#     554     sparkConf.set(key, value)
#     555 # This SparkContext may be an existing one.
# --> 556 sc = SparkContext.getOrCreate(sparkConf)
#     557 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     558 # by all sessions.
#     559 session = SparkSession(sc, options=self._options)
#
# File c:\Users\Admin\OneDrive\Documents\10Alytics_Training\pyspark\Nuga_Project\Nuga_bank_etl_case_study\.venv\Lib\site-packages\pyspark\core\context.py:523, in SparkContext.getOrCreate(cls, conf)
#     521 with SparkContext._lock:
#     522     if SparkContext._active_spark_context is None:
# --> 523         SparkContext(conf=conf or SparkConf())
#     524     assert SparkContext._active_spark_context is not None
#     525     return SparkContext._active_spark_context
#
# File c:\Users\Admin\OneDrive\Documents\10Alytics_Training\pyspark\Nuga_Project\Nuga_bank_etl_case_study\.venv\Lib\site-packages\pyspark\core\context.py:205, in SparkContext.__init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls, udf_profiler_cls, memory_profiler_cls)
#     199 if gateway is not None and gateway.gateway_parameters.auth_token is None:
#     200     raise ValueError(
#     201         "You are trying to pass an insecure Py4j gateway to Spark. This"
#     202         " is not allowed as it is a security risk."
#     203     )
# --> 205 SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     206 try:
#     207     self._do_init(
#     208         master,
#     209         appName,
#    (...)    219         memory_profiler_cls,
#     220     )
#
# File c:\Users\Admin\OneDrive\Documents\10Alytics_Training\pyspark\Nuga_Project\Nuga_bank_etl_case_study\.venv\Lib\site-packages\pyspark\core\context.py:444, in SparkContext._ensure_initialized(cls, instance, gateway, conf)
#     442 with SparkContext._lock:
#     443     if not SparkContext._gateway:
# --> 444         SparkContext._gateway = gateway or launch_gateway(conf)
#     445         SparkContext._jvm = SparkContext._gateway.jvm
#     447     if instance:
#
# File c:\Users\Admin\OneDrive\Documents\10Alytics_Training\pyspark\Nuga_Project\Nuga_bank_etl_case_study\.venv\Lib\site-packages\pyspark\java_gateway.py:108, in launch_gateway(conf, popen_kwargs)
#     106 # Wait for the file to appear, or for the process to exit, whichever happens first.
#     107 while not proc.poll() and not os.path.isfile(conn_info_file):
# --> 108     time.sleep(0.1)
#     110 if not os.path.isfile(conn_info_file):
#     111     raise PySparkRuntimeError(
#     112         errorClass="JAVA_GATEWAY_EXITED",
#     113         messageParameters={},
#     114     )
#
# KeyboardInterrupt:

# %%
# Initialise our Spark Session
spark = SparkSession.builder \
    .appName('Nuga Bank ETL') \
    .config("spark.jars", "postgresql-42.7.8.jar") \
        .getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 5
#       1 # Initialise my Spark Session
#       2 spark = SparkSession.builder \
#       3         .appName("Nuga Bank ETL") \
#       4         .config("spark.jars", "postgresql-42.7.8.jar") \
# ----> 5         .getOrCreate()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyspark\sql\session.py:556, in SparkSession.Builder.getOrCreate(self)
#     554     sparkConf.set(key, value)
#     555 # This SparkContext may be an existing one.
# --> 556 sc = SparkContext.getOrCreate(sparkConf)
#     557 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     558 # by all sessions.
#     559 session = SparkSession(sc, options=self._options)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyspark\core\context.py:523, in SparkContext.getOrCreate(cls, conf)
#     521 with SparkContext._lock:
#     522     if SparkContext._active_spark_context is None:
# --> 523         SparkContext(conf=conf or SparkConf())
#     524     assert SparkContext._active_spark_context is not None
#     525     return SparkContext._active_spark_context
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyspark\core\context.py:205, in SparkContext.__init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls, udf_profiler_cls, memory_profiler_cls)
#     199 if gateway is not None and gateway.gateway_parameters.auth_token is None:
#     200     raise ValueError(
#     201         "You are trying to pass an insecure Py4j gateway to Spark. This"
#     202         " is not allowed as it is a security risk."
#     203     )
# --> 205 SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     206 try:
#     207     self._do_init(
#     208         master,
#     209         appName,
#    (...)    219         memory_profiler_cls,
#     220     )
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyspark\core\context.py:444, in SparkContext._ensure_initialized(cls, instance, gateway, conf)
#     442 with SparkContext._lock:
#     443     if not SparkContext._gateway:
# --> 444         SparkContext._gateway = gateway or launch_gateway(conf)
#     445         SparkContext._jvm = SparkContext._gateway.jvm
#     447     if instance:
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyspark\java_gateway.py:108, in launch_gateway(conf, popen_kwargs)
#     106 # Wait for the file to appear, or for the process to exit, whichever happens first.
#     107 while not proc.poll() and not os.path.isfile(conn_info_file):
# --> 108     time.sleep(0.1)
#     110 if not os.path.isfile(conn_info_file):
#     111     raise PySparkRuntimeError(
#     112         errorClass="JAVA_GATEWAY_EXITED",
#     113         messageParameters={},
#     114     )
#
# KeyboardInterrupt:

# %%
spark
